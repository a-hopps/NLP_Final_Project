# %% [markdown]
# For google colab environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/Carleton/NLP/FinalProject/Dinu/03_Classifier/__ColabEnvironment"
# Out:
# /content/drive/MyDrive/Carleton/NLP/FinalProject/Dinu/03_Classifier/__ColabEnvironment

# %%
# install dependencies

# !pip install scikit-multilearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import sys
import os

# Add the parent directory of app_config to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
print(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Out:
# /content/drive/MyDrive/Carleton/NLP/FinalProject/Dinu/03_Classifier

# %%
from app_config import AppConfig

# define configuration proxy
configProxy = AppConfig()
CONFIG = configProxy.return_config()

print(CONFIG['BASE_DIR'])
# Out:
# /content/drive/MyDrive/Carleton/NLP/FinalProject/Dinu

# %% [markdown]
# Start code here

# %%
CONFIG[f'TOP_{10}_TESTING_DATASET_PATH']
# Out:
# '/content/drive/MyDrive/Carleton/NLP/FinalProject/Dinu/01_TASK_DATASETS/03_Task_Datasets/01_DATASETS_W_TAG_ENCODING/OUR_DATASET/top_10_testing_dataset.csv'

# %%
import os
from app_src import DecisionTreeEvaluator
from app_config import AppConfig

configProxy = AppConfig()
CONFIG = configProxy.return_config()

NUMBER_OF_TAGS = 10

decisionTreeEvaluator = DecisionTreeEvaluator()

# Get individual probability predictions
predictions_df = decisionTreeEvaluator.get_individual_predictions(
    encoder_batch_size=32,
    number_of_tags=NUMBER_OF_TAGS,
    estimator_name='GaussianNB',
    transformer_name='sentence-transformers/all-mpnet-base-v2',
    transformer_model_path='Sauron0019/DA-all-mpnet-base-v2-Top10-OurDataset',
    output_path='predictions_with_probabilities_NB.csv'  # Optional: save to CSV
)

# View the predictions
print(predictions_df.head())
print(f"\nTotal rows: {len(predictions_df)}")
print(f"Number of classes: {predictions_df.filter(like='prob_class_').shape[1]}")
# Out:
# All model checkpoint layers were used when initializing TFMPNetModel.
#
# All the layers of TFMPNetModel were initialized from the model checkpoint at Sauron0019/DA-all-mpnet-base-v2-Top10-OurDataset.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMPNetModel for predictions without further training.
# Loaded transformer model from: Sauron0019/DA-all-mpnet-base-v2-Top10-OurDataset
# Using GPU
# Encoding problem statements: 100%|██████████| 44/44 [00:58<00:00,  1.33s/it]
# Using estimator: GaussianNB
# Using GPU
# Encoding problem statements: 100%|██████████| 156/156 [03:33<00:00,  1.37s/it]
# Predictions saved to: predictions_with_probabilities_NB.csv
#                                    problem_statement  \
# 0  You are given an integer n Check if n has an d...
# 1  You are given an array a of 2n integers You wa...
# 2  Monocarp has just learned a new card trick and...
# 3  Pak Chanek has n blank heart shaped cards Card...
# ...

# %%
import os
from app_src import DecisionTreeEvaluator
from app_config import AppConfig

configProxy = AppConfig()
CONFIG = configProxy.return_config()

NUMBER_OF_TAGS = 10

decisionTreeEvaluator = DecisionTreeEvaluator()

# Get individual probability predictions
predictions_df = decisionTreeEvaluator.get_individual_predictions(
    encoder_batch_size=32,
    number_of_tags=NUMBER_OF_TAGS,
    estimator_name='GaussianNB',
    transformer_name='sentence-transformers/all-mpnet-base-v2',
    transformer_model_path='Sauron0019/DA-all-mpnet-base-v2-Top10-OurDataset',
    output_path='predictions_with_probabilities_NB.csv'  # Optional: save to CSV
)

# View the predictions
print(predictions_df.head())
print(f"\nTotal rows: {len(predictions_df)}")
print(f"Number of classes: {predictions_df.filter(like='prob_class_').shape[1]}")
